# %%
def lorenz(W, sigma, r, b):
    """ Lorenz system of ODEs
    
    Parameters
    ----------
    X : float or int
        current value of X
    Y : float or int
        current value of Y
    Z : float or int
        current value of Z
    sigma : float
        the Prandtl number
    r : float
        the Rayleigh number
    b : float
        dimensionless length scale
    
    Returns
    -------
    list of float (length 3)
        the derivative values of each of X, Y, and Z
    """
    
    X_prime = -sigma*(X - Y)
    Y_prime = r*X - Y - XZ
    Z_prime = -b*Z + XY
    
    return [X_prime, Y_prime, Z_prime]
